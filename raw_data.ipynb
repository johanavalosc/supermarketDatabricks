# %% [markdown]
# # Capa Raw (Landing Zone)
# El objetivo de este notebook es unicamente ingerir los datos desde la fuente (Kaggle) y depositarlos en nuestra zona de aterrizaje (Volumes) sin ninguna transofrmacion.

# %%
# %pip install kaggle

# %%
import os

# Credenciales de Kaggle (Idealmente deberian estar en Databricks Secrets)
os.environ['KAGGLE_USERNAME'] = "johanavalos"
os.environ['KAGGLE_KEY'] = "61b08977ac4d777b4a086bfe43641e5e"

# %%
# Definir e inicializar la ruta de descarga en el Volumen de Databricks
download_place = "/Volumes/workspace/supermarket/supermarket_data/supermarket_data_kaggle"
dbutils.fs.mkdirs(download_place)

# %%
# Descargar y descomprimir el dataset directamente en la capa Raw
# !kaggle datasets download -d "ismatkhan121/supermarket-sales-dataset" -p {download_place} --unzip

print(f"Datos descargados exitosamente en: {download_place}")
